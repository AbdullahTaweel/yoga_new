# %%
#MoveNET
import tensorflow as tf
import tensorflow_hub as hub
import numpy as np
import os
import cv2
import csv
# Out:
# 2024-07-04 00:17:28.858311: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Load MoveNet Thunder model from TensorFlow Hub
model_url = "https://tfhub.dev/google/movenet/singlepose/thunder/4"
movenet = hub.load(model_url)

print("MoveNet model loaded successfully.")
# Out:
# 2024-07-03 19:26:54.498876: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-03 19:27:00.100200: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# MoveNet model loaded successfully.

# %%
def load_and_preprocess_image(image_path):
    # Read the image from file
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Image at path {image_path} could not be read.")
    
    # Resize image to 256x256
    image = cv2.resize(image, (256, 256))
    
    # Normalize image to [0, 1]
    image = image / 255.0
    
    # Add batch dimension
    image = np.expand_dims(image, axis=0).astype(np.float32)
    
    return image

# %%
# Function to detect keypoints
def detect_keypoints(image):
    # Convert image to tf.int32
    image = tf.cast(image, tf.int32)
    # Run model inference
    outputs = movenet.signatures['serving_default'](tf.constant(image))
    keypoints = outputs['output_0'].numpy().reshape(-1, 3)
    
    return keypoints

# %%
# Function to save keypoints with class name to CSV
def save_keypoints_with_class(keypoints, class_name, csv_path, headers):
    # Prepare the data row
    row = [class_name] + keypoints.flatten().tolist()
    
    # Check if the CSV file exists
    file_exists = os.path.isfile(csv_path)
    
    # Write to the CSV file
    with open(csv_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(headers)  # Write the headers if file doesn't exist
        writer.writerow(row)

# %%
# Define the base directories
images_base_dir = '../data/images'
keypoints_base_dir = '../data/keypoints'
os.makedirs(keypoints_base_dir, exist_ok=True)

# Define headers for the CSV file
headers = ["Class",
           "Nose_x", "Nose_y", "Nose_conf",
           "LeftEye_x", "LeftEye_y", "LeftEye_conf",
           "RightEye_x", "RightEye_y", "RightEye_conf",
           "LeftEar_x", "LeftEar_y", "LeftEar_conf",
           "RightEar_x", "RightEar_y", "RightEar_conf",
           "LeftShoulder_x", "LeftShoulder_y", "LeftShoulder_conf",
           "RightShoulder_x", "RightShoulder_y", "RightShoulder_conf",
           "LeftElbow_x", "LeftElbow_y", "LeftElbow_conf",
           "RightElbow_x", "RightElbow_y", "RightElbow_conf",
           "LeftWrist_x", "LeftWrist_y", "LeftWrist_conf",
           "RightWrist_x", "RightWrist_y", "RightWrist_conf",
           "LeftHip_x", "LeftHip_y", "LeftHip_conf",
           "RightHip_x", "RightHip_y", "RightHip_conf",
           "LeftKnee_x", "LeftKnee_y", "LeftKnee_conf",
           "RightKnee_x", "RightKnee_y", "RightKnee_conf",
           "LeftAnkle_x", "LeftAnkle_y", "LeftAnkle_conf",
           "RightAnkle_x", "RightAnkle_y", "RightAnkle_conf"]
# Function to process all images and extract keypoints
def process_images_and_extract_keypoints():
    for class_folder in os.listdir(images_base_dir):
        class_folder_path = os.path.join(images_base_dir, class_folder)
        if os.path.isdir(class_folder_path):
            class_name = class_folder
            for file in os.listdir(class_folder_path):
                if file.lower().endswith(('.jpg', '.jpeg', '.png')):
                    image_path = os.path.join(class_folder_path, file)
                    keypoints_path = os.path.join(keypoints_base_dir, class_name + '.csv')
                    os.makedirs(os.path.dirname(keypoints_path), exist_ok=True)

                    try:
                        # Load and preprocess image
                        image = load_and_preprocess_image(image_path)
                        # Extract keypoints
                        keypoints = detect_keypoints(image)
                        # Save keypoints with class name to a file
                        save_keypoints_with_class(keypoints, class_name, keypoints_path, headers)
                        print(f"Processed {image_path}, saved keypoints to {keypoints_path}")
                    except Exception as e:
                        print(f"Error processing {image_path}: {e}")

# Process all images
process_images_and_extract_keypoints()
# Out:
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_03.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_39.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_82.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_32.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_22.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_56.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_68.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_17.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_100.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_104.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_65.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_88.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_59.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_66.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_25.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_42.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_34.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_07.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_15.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_92.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_64.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_69.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_21.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_09.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_44.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_90.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_14.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_50.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_73.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_96.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_63.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_77.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_61.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_19.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_12.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_83.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_53.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_91.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_85.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_105.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_37.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_31.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_10.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_106.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_72.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_57.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_28.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_48.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_79.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_97.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_75.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_08.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_54.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_33.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_99.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_89.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_29.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_76.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_06.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_71.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_41.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_86.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_46.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_55.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_62.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_81.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_103.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_58.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_49.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_74.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_18.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_38.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_13.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_93.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_102.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_23.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_101.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_20.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_84.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_47.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_67.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_30.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_87.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_45.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_05.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_35.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_11.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_51.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_43.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_52.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_26.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_60.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_95.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_98.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_16.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_01.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_36.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_04.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_78.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_02.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_40.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_80.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_24.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_70.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_94.jpeg, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Upward_Facing_Two-Foot_Staff/Upward_Facing_Two-Foot_Staff_Pose_27.png, saved keypoints to ../data/keypoints/Upward_Facing_Two-Foot_Staff.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_27.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_08.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_01.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_111.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_119.png, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_16.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_39.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_86.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_116.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_63.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_13.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_49.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_22.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_66.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_131.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_55.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_28.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_121.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_106.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_30.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_40.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_67.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_31.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_136.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_59.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_139.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_112.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_36.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_37.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_02.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_134.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_14.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_45.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_44.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_89.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_123.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_142.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_122.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_127.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_73.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_130.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_79.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_33.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_90.png, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_10.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_71.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_94.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_52.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_51.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_65.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_15.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_26.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_43.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_17.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_47.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_84.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_64.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_50.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_69.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_62.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_103.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_76.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_82.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_128.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_138.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_12.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_58.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_125.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_42.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_41.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_24.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_11.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_87.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_104.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_35.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_110.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_53.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_57.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_135.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_108.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_124.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_115.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_137.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_06.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_92.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_85.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_114.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_126.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_98.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_61.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_21.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_95.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_99.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_03.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_81.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_83.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_117.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_101.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_129.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_91.png, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_32.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_140.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_25.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_133.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_34.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_113.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_29.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_109.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_107.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_70.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_118.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_74.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_56.png, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_75.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_46.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_88.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_105.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_18.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_80.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_23.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_20.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_77.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_141.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_97.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_54.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_72.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_04.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_120.png, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_132.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_96.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_38.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_09.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_93.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_60.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_07.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_19.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_102.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_100.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_05.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_48.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_78.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eight-Angle/Eight-Angle_Pose_68.jpeg, saved keypoints to ../data/keypoints/Eight-Angle.csv
# Processed ../data/images/Eagle/Eagle_Pose_72.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_89.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_153.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_134.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_74.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_149.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_88.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_104.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_129.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_136.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_182.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_169.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_106.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_76.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_43.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_36.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_126.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_07.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_94.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_174.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_04.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_77.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_144.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_139.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_165.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_146.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_68.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_33.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_60.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_75.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_183.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_116.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_96.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_37.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_26.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_90.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_39.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_40.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_15.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_112.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_138.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_147.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_59.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_125.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_93.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_181.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_119.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_99.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_02.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_124.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_31.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_84.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_151.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_62.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_156.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_45.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_175.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_16.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_28.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_86.png, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_08.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_115.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_97.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_98.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_11.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_120.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_172.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_05.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_143.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_114.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_177.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_70.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_171.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_34.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_41.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_56.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_49.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_57.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_47.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_20.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_55.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_12.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_163.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_159.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_176.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_44.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_168.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_173.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_131.png, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_42.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_152.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_118.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_111.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_32.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_117.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_14.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_179.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_92.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_65.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_66.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_142.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_61.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_164.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_178.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_30.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_161.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_25.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_80.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_83.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_141.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_150.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_113.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_06.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_54.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_170.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_67.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_127.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_51.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_03.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_167.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_137.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_27.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_18.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_69.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_132.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_140.png, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_158.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_52.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_10.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_21.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_48.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_63.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_122.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_46.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_102.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_13.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_29.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_100.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_17.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# Processed ../data/images/Eagle/Eagle_Pose_01.jpeg, saved keypoints to ../data/keypoints/Eagle.csv
# ...
# Processed ../data/images/Side_Plank/Side_Plank_Pose_265.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_24.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_35.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_178.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_27.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_170.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_254.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_234.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_71.png, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_191.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_217.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_70.png, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Side_Plank/Side_Plank_Pose_183.jpeg, saved keypoints to ../data/keypoints/Side_Plank.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_121.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_109.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_20.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_99.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_107.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_101.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_08.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_68.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_114.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_57.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_14.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_80.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_19.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_122.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_73.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_49.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_88.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_85.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_50.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_95.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_104.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_65.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_74.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_67.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_36.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_47.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_52.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_110.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_06.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_22.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_75.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_26.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_93.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_45.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_77.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_113.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_102.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_64.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_124.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_23.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_81.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_125.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_16.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_86.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_40.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_30.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_37.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_07.png, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_31.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_71.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_112.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_111.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_91.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_82.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_70.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_02.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_43.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_87.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_94.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_32.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_106.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_103.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_59.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_84.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_24.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_89.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_119.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_18.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_05.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_100.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_21.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_48.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_69.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_25.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_39.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_116.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_108.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_97.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_29.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_42.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_115.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_12.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_03.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_63.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_35.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_33.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_79.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_118.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_117.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_15.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_96.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_90.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_44.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_51.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_58.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_09.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_120.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_34.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_78.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_61.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_62.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_98.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_10.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_13.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_55.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_38.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_27.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_60.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_28.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_41.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_17.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_66.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_105.png, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_01.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_53.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_46.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_83.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_92.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_11.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_72.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_123.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_76.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_04.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_56.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv
# Processed ../data/images/Warrior_III/Warrior_III_Pose_54.jpeg, saved keypoints to ../data/keypoints/Warrior_III.csv

# %%
#LSTM MODEL
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.utils import to_categorical
# Out:
# 2024-07-04 14:33:18.792498: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
keypoints_base_dir = '../data/keypoints'
combined_csv_path = os.path.join(keypoints_base_dir, 'combined_keypoints.csv')

def combine_csv_files(base_dir, output_path):
    combined_df = pd.DataFrame()
    for file in os.listdir(base_dir):
        if file.endswith('.csv'):
            class_name = file.replace('.csv', '')
            file_path = os.path.join(base_dir, file)
            df = pd.read_csv(file_path)
            combined_df = pd.concat([combined_df, df], ignore_index=True)
    combined_df.to_csv(output_path, index=False)
    return combined_df

combined_df = combine_csv_files(keypoints_base_dir, combined_csv_path)
print(f"Combined CSV saved to {combined_csv_path}")
# Out:
# Combined CSV saved to ../data/keypoints/combined_keypoints.csv

# %%
# Load the combined CSV file
combined_csv_path = '../data/keypoints/combined_keypoints.csv'
df = pd.read_csv(combined_csv_path)

# Extract features (keypoints) and labels
X = df.iloc[:, 1:].values  # All columns except the first one are keypoints
y = df.iloc[:, 0].values   # The first column is the class label

# Check the shape of X
print(f"Shape of X: {X.shape}")  # Should be (num_samples, 51)

# Normalize features (keypoints)
X = (X - X.mean(axis=0)) / X.std(axis=0)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(y)
num_classes = len(label_encoder.classes_)
y_one_hot = to_categorical(encoded_labels, num_classes)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2, random_state=42)
# Out:
# Shape of X: (109816, 51)

# %%
# Reshape data for LSTM input: (samples, timesteps, features)
X_train = X_train.reshape(-1, 17, 3)  # 17 timesteps (keypoints) and 3 features (x, y, conf)
X_test = X_test.reshape(-1, 17, 3)

print(f"Reshaped X_train shape: {X_train.shape}")  # Should be (num_samples, 17, 3)
print(f"Reshaped X_test shape: {X_test.shape}")    # Should be (num_samples, 17, 3)
# Out:
# Reshaped X_train shape: (87852, 17, 3)
# Reshaped X_test shape: (21964, 17, 3)

# %%
from tensorflow.keras.layers import GRU
from tensorflow.keras.callbacks import EarlyStopping
def build_improved_lstm_model(input_shape, num_classes):
    model = Sequential()
    model.add(LSTM(128, input_shape=input_shape, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    return model

input_shape = (X_train.shape[1], X_train.shape[2])
model = build_improved_lstm_model(input_shape, num_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# 2024-07-04 14:35:36.188526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:36.189717: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:36.190804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1/50
# 2024-07-04 14:35:36.394111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:36.396476: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:36.397998: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:35:36.774075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:36.775737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:36.777066: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:35:36.999363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:37.001100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:37.002562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:35:38.024125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:38.025816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:38.027158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:35:38.249749: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:35:38.251388: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:35:38.252772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1373/1373 [==============================] - ETA: 0s - loss: 4.2743 - accuracy: 0.0404
# 2024-07-04 14:37:59.679434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:37:59.681204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:37:59.682563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:38:00.170410: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:38:00.172541: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:38:00.174195: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 21
#      18 early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#      20 # Train the model with early stopping
# ---> 21 history = model.fit(X_train, y_train, epochs=50, batch_size=64, validation_data=(X_test, y_test), callbacks=[early_stopping])
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/engine/training.py:1729, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1714 if getattr(self, "_eval_data_handler", None) is None:
#    1715     self._eval_data_handler = data_adapter.get_data_handler(
#    1716         x=val_x,
#    1717         y=val_y,
#    (...)
#    1727         steps_per_execution=self._steps_per_execution,
#    1728     )
# -> 1729 val_logs = self.evaluate(
#    1730     x=val_x,
#    1731     y=val_y,
#    1732     sample_weight=val_sample_weight,
#    1733     batch_size=validation_batch_size or batch_size,
#    1734     steps=validation_steps,
#    1735     callbacks=callbacks,
#    1736     max_queue_size=max_queue_size,
#    1737     workers=workers,
#    1738     use_multiprocessing=use_multiprocessing,
#    1739     return_dict=True,
#    1740     _use_cached_eval_dataset=True,
#    1741 )
#    1742 val_logs = {
#    1743     "val_" + name: val for name, val in val_logs.items()
#    1744 }
#    1745 epoch_logs.update(val_logs)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/engine/training.py:2072, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2068 with tf.profiler.experimental.Trace(
#    2069     "test", step_num=step, _r=1
#    2070 ):
#    2071     callbacks.on_test_batch_begin(step)
# -> 2072     tmp_logs = self.test_function(iterator)
#    2073     if data_handler.should_sync:
#    2074         context.async_wait()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:933, in Function._call(self, *args, **kwds)
#     930 self._lock.release()
#     931 # In this case we have not created variables on the first call. So we can
#     932 # run the first trace but we should fail if variables are created.
# --> 933 results = self._variable_creation_fn(*args, **kwds)
#     934 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     935   raise ValueError("Creating variables on a non-first call to a function"
#     936                    " decorated with tf.function.")
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:143, in TracingCompiler.__call__(self, *args, **kwargs)
#     140 with self._lock:
#     141   (concrete_function,
#     142    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143 return concrete_function._call_flat(
#     144     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1757, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1753 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1754 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1755     and executing_eagerly):
#    1756   # No tape is watching; skip to running the function.
# -> 1757   return self._build_call_outputs(self._inference_function.call(
#    1758       ctx, args, cancellation_manager=cancellation_manager))
#    1759 forward_backward = self._select_forward_and_backward_functions(
#    1760     args,
#    1761     possible_gradient_type,
#    1762     executing_eagerly)
#    1763 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:381, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     379 with _InterpolateFunctionError(self):
#     380   if cancellation_manager is None:
# --> 381     outputs = execute.execute(
#     382         str(self.signature.name),
#     383         num_outputs=self._num_outputs,
#     384         inputs=args,
#     385         attrs=attrs,
#     386         ctx=ctx)
#     387   else:
#     388     outputs = execute.execute_with_cancellation(
#     389         str(self.signature.name),
#     390         num_outputs=self._num_outputs,
#    (...)
#     393         ctx=ctx,
#     394         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss:.4f}, Accuracy: {accuracy:.4f}')

# Predict classes
y_pred_probs = model.predict(X_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Compute confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(20, 20))  # Adjust the figure size for better visualization
sns.heatmap(conf_matrix, annot=False, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 601/601 [==============================] - 10s 16ms/step - loss: 2.7802 - accuracy: 0.3572
# Loss: 2.7802, Accuracy: 0.3572
# 2024-07-04 14:08:54.538990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:08:54.541379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:08:54.543162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-07-04 14:08:54.760467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-07-04 14:08:54.762659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-07-04 14:08:54.764414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 601/601 [==============================] - 11s 17ms/step

# %%
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

print("Classification Report:")
print(classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# 86/86 [==============================] - 2s 17ms/step
# Test Accuracy: 3.53%
# Classification Report:
#                                 precision    recall  f1-score   support
#
#        Bharadvaja's_Twist_pose       0.00      0.00      0.00        22
#                           Boat       0.00      0.00      0.00        49
#                    Bound_Angle       0.00      0.00      0.00        37
#            Bow_or_Dhanurasana_       0.00      0.00      0.00        38
#                         Bridge       0.00      0.00      0.00        32
#                          Camel       0.00      0.00      0.00        28
#                        Cat_Cow       0.00      0.00      0.00        39
#                          Chair       0.00      0.00      0.00        28
#                          Child       0.00      0.00      0.00        39
#                          Cobra       0.04      1.00      0.07        97
#                       Cockerel       0.00      0.00      0.00        23
#                         Corpse       0.00      0.00      0.00        37
#                       Cow_Face       0.00      0.00      0.00        32
#                           Crow       0.00      0.00      0.00        48
#                        Dolphin       0.00      0.00      0.00        20
#                  Dolphin_Plank       0.00      0.00      0.00        23
#            Downward-Facing_Dog       0.00      0.00      0.00        33
#                          Eagle       0.00      0.00      0.00        40
#                    Eight-Angle       0.00      0.00      0.00        31
#                 Extended_Puppy       0.00      0.00      0.00        16
#   Extended_Revolved_Side_Angle       0.00      0.00      0.00        79
#     Extended_Revolved_Triangle       0.00      0.00      0.00        67
#              Feathered_Peacock       0.00      0.00      0.00        23
#                        Firefly       0.00      0.00      0.00        25
#                           Fish       0.00      0.00      0.00        33
#              Four-Limbed_Staff       0.00      0.00      0.00        20
#                           Frog       0.00      0.00      0.00        22
#                        Garland       0.00      0.00      0.00        36
#                           Gate       0.00      0.00      0.00        26
#        Half_Lord_of_the_Fishes       0.00      0.00      0.00        46
#                      Half_Moon       0.00      0.00      0.00        36
#                 Handstand_pose       0.00      0.00      0.00        21
#                Happy_Baby_PosE       0.00      0.00      0.00        26
#      Head-to-Knee_Forward_Bend       0.00      0.00      0.00        26
#                           Hero       0.00      0.00      0.00        41
#                          Heron       0.00      0.00      0.00        27
#           Intense_Side_Stretch       0.00      0.00      0.00        15
#               Legs-Up-the-Wall       0.00      0.00      0.00        31
#                         Locust       0.00      0.00      0.00        27
#              Lord_of_the_Dance       0.00      0.00      0.00        41
#                      Low_Lunge       0.00      0.00      0.00        37
#                          Noose       0.00      0.00      0.00        15
#              One_Legged_Pigeon       0.00      0.00      0.00        40
#                        Peacock       0.00      0.00      0.00        22
#                         Pigeon       0.00      0.00      0.00        24
#                          Plank       0.00      0.00      0.00        37
#                           Plow       0.00      0.00      0.00        61
#          Reclining_Bound_Angle       0.00      0.00      0.00        45
#      Reclining_Hand-to-Big-Toe       0.00      0.00      0.00        38
#                Reverse_Warrior       0.00      0.00      0.00        34
#          Revolved_Head-to-Knee       0.00      0.00      0.00        36
#                 Sage_Koundinya       0.00      0.00      0.00        30
#                          Scale       0.00      0.00      0.00        29
#                       Scorpion       0.00      0.00      0.00        35
#            Seated_Forward_Bend       0.00      0.00      0.00        48
#              Shoulder-Pressing       0.00      0.00      0.00        25
#        Side-Reclining_Leg_Lift       0.00      0.00      0.00        20
#                      Side_Crow       0.00      0.00      0.00        27
#                     Side_Plank       0.00      0.00      0.00        57
#                        Sitting       0.00      0.00      0.00        78
#                          Split       0.00      0.00      0.00        14
#                          Staff       0.00      0.00      0.00        23
#          Standing_Forward_Bend       0.00      0.00      0.00        55
#                 Standing_Split       0.00      0.00      0.00        27
#          Standing_big_toe_hold       0.00      0.00      0.00        22
#            Supported_Headstand       0.00      0.00      0.00        45
#        Supported_Shoulderstand       0.00      0.00      0.00        21
#                 Supta_Virasana       0.00      0.00      0.00        40
#               The_Shooting_Bow       0.00      0.00      0.00        15
#                       Tortoise       0.00      0.00      0.00        25
#                           Tree       0.00      0.00      0.00        35
#                     Upward_Bow       0.00      0.00      0.00        36
#   Upward_Facing_Two-Foot_Staff       0.00      0.00      0.00        19
#                   Upward_Plank       0.00      0.00      0.00        41
#                      Warrior_I       0.00      0.00      0.00        26
#                     Warrior_II       0.00      0.00      0.00        42
#                    Warrior_III       0.00      0.00      0.00        16
# Wide-Angle_Seated_Forward_Bend       0.00      0.00      0.00        26
#       Wide-Legged_Forward_Bend       0.00      0.00      0.00        31
#                     Wild_Thing       0.00      0.00      0.00        31
#                 Wind_Relieving       0.00      0.00      0.00        17
#                    Yogic_sleep       0.00      0.00      0.00        21
#
#                       accuracy                           0.04      2746
#                      macro avg       0.00      0.01      0.00      2746
#                   weighted avg       0.00      0.04      0.00      2746
# /home/abdulah/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/abdulah/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/abdulah/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Reverse transform encoded labels back to original class labels
predicted_classes = label_encoder.inverse_transform(y_pred_classes)

# Display some predictions
for i in range(100):  # Displaying first 10 predictions
    print(f"Predicted: {predicted_classes[i]}, Actual: {label_encoder.inverse_transform([y_test[i]])[0]}")
# Out:
# Predicted: Cobra, Actual: Downward-Facing_Dog
# Predicted: Cobra, Actual: Happy_Baby_PosE
# Predicted: Cobra, Actual: Heron
# Predicted: Cobra, Actual: Eagle
# Predicted: Cobra, Actual: Lord_of_the_Dance
# Predicted: Cobra, Actual: Supported_Headstand
# Predicted: Cobra, Actual: Tortoise
# Predicted: Cobra, Actual: Sage_Koundinya
# Predicted: Cobra, Actual: Bridge
# Predicted: Cobra, Actual: Gate
# Predicted: Cobra, Actual: Intense_Side_Stretch
# Predicted: Cobra, Actual: Crow
# Predicted: Cobra, Actual: Four-Limbed_Staff
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Warrior_II
# Predicted: Cobra, Actual: Eagle
# Predicted: Cobra, Actual: Plow
# Predicted: Cobra, Actual: Shoulder-Pressing
# Predicted: Cobra, Actual: Seated_Forward_Bend
# Predicted: Cobra, Actual: Supta_Virasana
# Predicted: Cobra, Actual: Wide-Legged_Forward_Bend
# Predicted: Cobra, Actual: Cobra
# Predicted: Cobra, Actual: Supported_Headstand
# Predicted: Cobra, Actual: Lord_of_the_Dance
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Yogic_sleep
# Predicted: Cobra, Actual: Garland
# Predicted: Cobra, Actual: Standing_Forward_Bend
# Predicted: Cobra, Actual: Wide-Angle_Seated_Forward_Bend
# Predicted: Cobra, Actual: Dolphin
# Predicted: Cobra, Actual: Wind_Relieving
# Predicted: Cobra, Actual: Side_Plank
# Predicted: Cobra, Actual: Warrior_I
# Predicted: Cobra, Actual: Locust
# Predicted: Cobra, Actual: Scale
# Predicted: Cobra, Actual: Standing_Forward_Bend
# Predicted: Cobra, Actual: Tree
# Predicted: Cobra, Actual: Boat
# Predicted: Cobra, Actual: Bound_Angle
# Predicted: Cobra, Actual: Upward_Bow
# Predicted: Cobra, Actual: Standing_big_toe_hold
# Predicted: Cobra, Actual: Supported_Headstand
# Predicted: Cobra, Actual: Sitting
# Predicted: Cobra, Actual: Wide-Legged_Forward_Bend
# Predicted: Cobra, Actual: Upward_Plank
# Predicted: Cobra, Actual: Hero
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Intense_Side_Stretch
# Predicted: Cobra, Actual: Tree
# Predicted: Cobra, Actual: Reclining_Bound_Angle
# Predicted: Cobra, Actual: Extended_Puppy
# Predicted: Cobra, Actual: Revolved_Head-to-Knee
# Predicted: Cobra, Actual: Feathered_Peacock
# Predicted: Cobra, Actual: Cow_Face
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Sitting
# Predicted: Cobra, Actual: Child
# Predicted: Cobra, Actual: Upward_Bow
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Peacock
# Predicted: Cobra, Actual: Upward_Plank
# Predicted: Cobra, Actual: Crow
# Predicted: Cobra, Actual: Standing_Forward_Bend
# Predicted: Cobra, Actual: Plank
# Predicted: Cobra, Actual: Standing_Split
# Predicted: Cobra, Actual: Cow_Face
# Predicted: Cobra, Actual: Dolphin
# Predicted: Cobra, Actual: Standing_big_toe_hold
# Predicted: Cobra, Actual: Wild_Thing
# Predicted: Cobra, Actual: Side_Plank
# Predicted: Cobra, Actual: Upward_Plank
# Predicted: Cobra, Actual: Firefly
# Predicted: Cobra, Actual: Handstand_pose
# Predicted: Cobra, Actual: Wild_Thing
# Predicted: Cobra, Actual: Warrior_I
# Predicted: Cobra, Actual: Plow
# Predicted: Cobra, Actual: Sitting
# Predicted: Cobra, Actual: Reclining_Hand-to-Big-Toe
# Predicted: Cobra, Actual: Warrior_II
# Predicted: Cobra, Actual: One_Legged_Pigeon
# Predicted: Cobra, Actual: Eight-Angle
# Predicted: Cobra, Actual: Extended_Revolved_Side_Angle
# Predicted: Cobra, Actual: Wind_Relieving
# Predicted: Cobra, Actual: Lord_of_the_Dance
# Predicted: Cobra, Actual: Tree
# Predicted: Cobra, Actual: Chair
# Predicted: Cobra, Actual: Camel
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Cat_Cow
# Predicted: Cobra, Actual: Extended_Revolved_Side_Angle
# Predicted: Cobra, Actual: Corpse
# Predicted: Cobra, Actual: Reverse_Warrior
# Predicted: Cobra, Actual: Bridge
# Predicted: Cobra, Actual: Half_Moon
# Predicted: Cobra, Actual: Scorpion
# Predicted: Cobra, Actual: Eagle
# Predicted: Cobra, Actual: Sage_Koundinya
# Predicted: Cobra, Actual: Upward_Bow
# Predicted: Cobra, Actual: Yogic_sleep
# Predicted: Cobra, Actual: Supported_Headstand

# %%
model.save('yoga_pose_classifier.h5')
#end of LSTM Model

# %%
#neural network

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize the feature data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Build the neural network
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Test accuracy: {test_accuracy:.4f}')

# Save the model for future use
model.save('yoga_pose_classifier.h5')

# %%
#classifier_Random_Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize the model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Random Forest accuracy: {accuracy:.4f}')

# %%
#Classifier_SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Initialize the model
svm_model = SVC(kernel='linear', C=1.0, random_state=42)

# Train the model
svm_model.fit(X_train, y_train)

# Make predictions
y_pred = svm_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'SVM accuracy: {accuracy:.4f}')

# %%
#Classic_CNN
